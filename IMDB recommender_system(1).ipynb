# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("movies_metadata.csv")
# Out:
# C:\Users\student\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (45466, 24)

# %%
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
# Select the second movie in a datafame
second = df.iloc[1]
second
# Out:
# adult                                                                False
# belongs_to_collection                                                  NaN
# budget                                                            65000000
# genres                   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# homepage                                                               NaN
# id                                                                    8844
# imdb_id                                                          tt0113497
# original_language                                                       en
# original_title                                                     Jumanji
# overview                 When siblings Judy and Peter discover an encha...
# popularity                                                         17.0155
# poster_path                               /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=45466, step=1)

# %%
# Change the index to the title
df = df.set_index("title")
df.head()
# Out:
#                              adult  \
# title
# Toy Story                    False
# Jumanji                      False
# Grumpier Old Men             False
# Waiting to Exhale            False
# Father of the Bride Part II  False
#
#                                                          belongs_to_collection  \
# title
# Toy Story                    {'id': 10194, 'name': 'Toy Story Collection', ...
# Jumanji                                                                    NaN
# Grumpier Old Men             {'id': 119050, 'name': 'Grumpy Old Men Collect...
# Waiting to Exhale                                                          NaN
# Father of the Bride Part II  {'id': 96871, 'name': 'Father of the Bride Col...
#
#                                budget  \
# title
# Toy Story                    30000000
# Jumanji                      65000000
# Grumpier Old Men                    0
# Waiting to Exhale            16000000
# Father of the Bride Part II         0
#
# ...

# %%
df.loc["Jumanji"]
# Out:
# adult                                                                False
# belongs_to_collection                                                  NaN
# budget                                                            65000000
# genres                   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# homepage                                                               NaN
# id                                                                    8844
# imdb_id                                                          tt0113497
# original_language                                                       en
# original_title                                                     Jumanji
# overview                 When siblings Judy and Peter discover an encha...
# popularity                                                         17.0155
# poster_path                               /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# ...

# %%
# Revert back to the previous zero based indexing
df = df.reset_index()

df.head()
# Out:
#                          title  adult  \
# 0                    Toy Story  False
# 1                      Jumanji  False
# 2             Grumpier Old Men  False
# 3            Waiting to Exhale  False
# 4  Father of the Bride Part II  False
#
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
# ...

# %%
m = df["vote_count"].quantile(0.90)
m
# Out:
# 160.0

# %%
df["vote_count"].quantile(0.80)
# Out:
# 50.0

# %%
# Only consider movies longer than 45 minutes and shorter than 300 minutes
q_movies = df[(df['runtime'] >= 45)& (df["runtime"] <= 300)]
q_movies.runtime
# Out:
# 0         81.0
# 1        104.0
# 2        101.0
# 3        127.0
# 4        106.0
#          ...
# 45460    104.0
# 45461     90.0
# 45463     90.0
# 45464     87.0
# 45465     75.0
# Name: runtime, Length: 41930, dtype: float64

# %%
len(q_movies)
# Out:
# 41930

# %%
# Only consider movies that have garnered more than m votes
q_movies = q_movies[q_movies["vote_count"]>= 50 ]

# Inspect the number of movies that made the cut
q_movies.shape
# Out:
# (8963, 24)

# %%
# Calculating the Scores
C = df['vote_average'].mean()
C
# Out:
# 5.618207215133889

# %%
def weighted_rating(X, m=m, C=C):
    V = X["vote_count"]
    R = X["vote_average"]
    #Compute the weighted score
    return (V/(V+m)*R)+(m/(m+V)*C)

# %%
q_movies.columns
# Out:
# Index(['title', 'adult', 'belongs_to_collection', 'budget', 'genres',
#        'homepage', 'id', 'imdb_id', 'original_language', 'original_title',
#        'overview', 'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'video', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
q_movies["score"] = q_movies.apply(weighted_rating, axis=1)

# %%
q_movies.head().T
# Out:
#                                                                        0  \
# title                                                          Toy Story
# adult                                                              False
# belongs_to_collection  {'id': 10194, 'name': 'Toy Story Collection', ...
# budget                                                          30000000
# genres                 [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# homepage                            http://toystory.disney.com/toy-story
# id                                                                   862
# imdb_id                                                        tt0114709
# original_language                                                     en
# original_title                                                 Toy Story
# overview               Led by Woody, Andy's toys live happily in his ...
# popularity                                                       21.9469
# ...

# %%
q_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8963 entries, 0 to 45441
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  8963 non-null   object
#  1   adult                  8963 non-null   object
#  2   belongs_to_collection  1972 non-null   object
#  3   budget                 8963 non-null   object
#  4   genres                 8963 non-null   object
#  5   homepage               2739 non-null   object
#  6   id                     8963 non-null   object
#  7   imdb_id                8963 non-null   object
#  8   original_language      8963 non-null   object
#  9   original_title         8963 non-null   object
#  10  overview               8953 non-null   object
#  11  popularity             8963 non-null   object
#  12  poster_path            8963 non-null   object
#  13  production_companies   8963 non-null   object
# ...

# %%
sort = q_movies["score"].sort_values(ascending=False)

# %%
index = sort.index

# %%
recommender_system = q_movies.loc[index]

# %%
recommender_system["title"].head(25)
# Out:
# 314                           The Shawshank Redemption
# 834                                      The Godfather
# 10309                      Dilwale Dulhania Le Jayenge
# 12481                                  The Dark Knight
# 2843                                        Fight Club
# 292                                       Pulp Fiction
# 522                                   Schindler's List
# 23673                                         Whiplash
# 5481                                     Spirited Away
# 2211                                 Life Is Beautiful
# 1178                            The Godfather: Part II
# 1152                   One Flew Over the Cuckoo's Nest
# 351                                       Forrest Gump
# 1154                           The Empire Strikes Back
# 1176                                            Psycho
# 18465                                 The Intouchables
# 40251                                       Your Name.
# ...

# %%
q_movies.genres
# Out:
# 0        [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1        [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2        [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 4                           [{'id': 35, 'name': 'Comedy'}]
# 5        [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
#                                ...
# 45268                       [{'id': 35, 'name': 'Comedy'}]
# 45339                       [{'id': 35, 'name': 'Comedy'}]
# 45343                       [{'id': 35, 'name': 'Comedy'}]
# 45348    [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 45441                       [{'id': 35, 'name': 'Comedy'}]
# Name: genres, Length: 8963, dtype: object
